# %%
# Test 3-1 Dataset 3 v2
# This test uses the new dataset 16000 images
# This test uses a simple CNN to classify between having an Square or a Circle

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.utils import image_dataset_from_directory
tf.config.list_physical_devices('GPU')
# Out:
# 2024-04-14 23:13:27.294872: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-14 23:13:27.294923: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-14 23:13:27.327391: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-14 23:13:27.391854: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-14 23:13:28.319539: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-14 23:13:31.222696: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-14 23:13:31.341729: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-14 23:13:31.341899: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
train_dir = '../../Dataset_Scripts/Datasets/Dataset_3/train'
test_dir = '../../Dataset_Scripts/Datasets/Dataset_3/test'

# %%
IMG_SIZE = 250
BATCH_SIZE = 32
RANDOM_SEED = random.randint(0, 1000)
print(RANDOM_SEED)
# Out:
# 80

# %%
train_dataset = image_dataset_from_directory(
    train_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    seed=RANDOM_SEED,
    shuffle=False,
    )

test_dataset = image_dataset_from_directory(
    test_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    seed=RANDOM_SEED,
    shuffle=False
    )
# Out:
# Found 11000 files belonging to 2 classes.
# 2024-04-14 23:13:31.713230: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-14 23:13:31.713443: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-14 23:13:31.713549: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-14 23:13:31.770709: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-14 23:13:31.770865: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-14 23:13:31.771001: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-14 23:13:31.771090: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4273 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2024-04-14 23:13:32.011803: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Found 5000 files belonging to 2 classes.

# %%
for data_batch, _ in train_dataset.take(1):
    for i in range(5):
        plt.imshow(data_batch[i].numpy().astype("uint8"))
        plt.show()

# %%
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
x = layers.Dense(512, activation="relu")(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(loss="binary_crossentropy", optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4), metrics=['acc'])

# %%
checkpoint_filepath = 'models/3-1/ch-{epoch:03d}.ckpt'
callbacks = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_best_only=True,
    monitor='val_loss',
    verbose=1)

# %%
#Best Epoch = ?

history = model.fit(train_dataset, epochs=30, batch_size=32, validation_data=test_dataset, callbacks=[callbacks])
# Out:
# Epoch 1/30
# 2024-04-14 17:30:24.435205: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2024-04-14 17:30:24.551590: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-04-14 17:30:25.773866: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fe4d8489de0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-04-14 17:30:25.773889: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2024-04-14 17:30:25.778880: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1713112225.834727   20953 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 344/344 [==============================] - ETA: 0s - loss: 0.6011 - acc: 0.6521
# Epoch 1: val_loss improved from inf to 0.53835, saving model to models/3-1/ch-001.ckpt
# INFO:tensorflow:Assets written to: models/3-1/ch-001.ckpt/assets
# INFO:tensorflow:Assets written to: models/3-1/ch-001.ckpt/assets
# 344/344 [==============================] - 33s 79ms/step - loss: 0.6011 - acc: 0.6521 - val_loss: 0.5383 - val_acc: 0.7144
# Epoch 2/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.5300 - acc: 0.7188
# Epoch 2: val_loss improved from 0.53835 to 0.50362, saving model to models/3-1/ch-002.ckpt
# INFO:tensorflow:Assets written to: models/3-1/ch-002.ckpt/assets
# INFO:tensorflow:Assets written to: models/3-1/ch-002.ckpt/assets
# 344/344 [==============================] - 25s 73ms/step - loss: 0.5301 - acc: 0.7189 - val_loss: 0.5036 - val_acc: 0.7378
# Epoch 3/30
# 344/344 [==============================] - ETA: 0s - loss: 0.4859 - acc: 0.7518
# Epoch 3: val_loss improved from 0.50362 to 0.46091, saving model to models/3-1/ch-003.ckpt
# INFO:tensorflow:Assets written to: models/3-1/ch-003.ckpt/assets
# INFO:tensorflow:Assets written to: models/3-1/ch-003.ckpt/assets
# 344/344 [==============================] - 22s 65ms/step - loss: 0.4859 - acc: 0.7518 - val_loss: 0.4609 - val_acc: 0.7668
# Epoch 4/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.4379 - acc: 0.7844
# Epoch 4: val_loss improved from 0.46091 to 0.40572, saving model to models/3-1/ch-004.ckpt
# INFO:tensorflow:Assets written to: models/3-1/ch-004.ckpt/assets
# INFO:tensorflow:Assets written to: models/3-1/ch-004.ckpt/assets
# 344/344 [==============================] - 25s 71ms/step - loss: 0.4377 - acc: 0.7845 - val_loss: 0.4057 - val_acc: 0.7980
# Epoch 5/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.3753 - acc: 0.8208
# Epoch 5: val_loss improved from 0.40572 to 0.34775, saving model to models/3-1/ch-005.ckpt
# INFO:tensorflow:Assets written to: models/3-1/ch-005.ckpt/assets
# INFO:tensorflow:Assets written to: models/3-1/ch-005.ckpt/assets
# 344/344 [==============================] - 24s 70ms/step - loss: 0.3753 - acc: 0.8210 - val_loss: 0.3478 - val_acc: 0.8368
# Epoch 6/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.2936 - acc: 0.8694
# Epoch 6: val_loss improved from 0.34775 to 0.30330, saving model to models/3-1/ch-006.ckpt
# INFO:tensorflow:Assets written to: models/3-1/ch-006.ckpt/assets
# INFO:tensorflow:Assets written to: models/3-1/ch-006.ckpt/assets
# 344/344 [==============================] - 25s 71ms/step - loss: 0.2934 - acc: 0.8695 - val_loss: 0.3033 - val_acc: 0.8390
# Epoch 7/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.2200 - acc: 0.9067
# Epoch 7: val_loss improved from 0.30330 to 0.21003, saving model to models/3-1/ch-007.ckpt
# INFO:tensorflow:Assets written to: models/3-1/ch-007.ckpt/assets
# INFO:tensorflow:Assets written to: models/3-1/ch-007.ckpt/assets
# 344/344 [==============================] - 24s 70ms/step - loss: 0.2200 - acc: 0.9067 - val_loss: 0.2100 - val_acc: 0.9112
# Epoch 8/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.1640 - acc: 0.9321
# Epoch 8: val_loss improved from 0.21003 to 0.18390, saving model to models/3-1/ch-008.ckpt
# INFO:tensorflow:Assets written to: models/3-1/ch-008.ckpt/assets
# INFO:tensorflow:Assets written to: models/3-1/ch-008.ckpt/assets
# 344/344 [==============================] - 24s 69ms/step - loss: 0.1639 - acc: 0.9322 - val_loss: 0.1839 - val_acc: 0.9212
# Epoch 9/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.1282 - acc: 0.9482
# Epoch 9: val_loss improved from 0.18390 to 0.16379, saving model to models/3-1/ch-009.ckpt
# INFO:tensorflow:Assets written to: models/3-1/ch-009.ckpt/assets
# INFO:tensorflow:Assets written to: models/3-1/ch-009.ckpt/assets
# 344/344 [==============================] - 25s 71ms/step - loss: 0.1284 - acc: 0.9480 - val_loss: 0.1638 - val_acc: 0.9314
# Epoch 10/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.1001 - acc: 0.9605
# Epoch 10: val_loss improved from 0.16379 to 0.12997, saving model to models/3-1/ch-010.ckpt
# INFO:tensorflow:Assets written to: models/3-1/ch-010.ckpt/assets
# INFO:tensorflow:Assets written to: models/3-1/ch-010.ckpt/assets
# 344/344 [==============================] - 25s 72ms/step - loss: 0.1001 - acc: 0.9605 - val_loss: 0.1300 - val_acc: 0.9460
# Epoch 11/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0796 - acc: 0.9703
# Epoch 11: val_loss did not improve from 0.12997
# 344/344 [==============================] - 24s 69ms/step - loss: 0.0796 - acc: 0.9704 - val_loss: 0.1337 - val_acc: 0.9480
# Epoch 12/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0655 - acc: 0.9743
# Epoch 12: val_loss did not improve from 0.12997
# 344/344 [==============================] - 24s 70ms/step - loss: 0.0657 - acc: 0.9741 - val_loss: 0.1467 - val_acc: 0.9468
# Epoch 13/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0534 - acc: 0.9804
# Epoch 13: val_loss improved from 0.12997 to 0.12409, saving model to models/3-1/ch-013.ckpt
# INFO:tensorflow:Assets written to: models/3-1/ch-013.ckpt/assets
# INFO:tensorflow:Assets written to: models/3-1/ch-013.ckpt/assets
# 344/344 [==============================] - 26s 74ms/step - loss: 0.0533 - acc: 0.9805 - val_loss: 0.1241 - val_acc: 0.9552
# Epoch 14/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0459 - acc: 0.9834
# Epoch 14: val_loss did not improve from 0.12409
# 344/344 [==============================] - 25s 73ms/step - loss: 0.0459 - acc: 0.9834 - val_loss: 0.1262 - val_acc: 0.9556
# Epoch 15/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0372 - acc: 0.9862
# Epoch 15: val_loss did not improve from 0.12409
# 344/344 [==============================] - 25s 71ms/step - loss: 0.0372 - acc: 0.9863 - val_loss: 0.1294 - val_acc: 0.9576
# Epoch 16/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0298 - acc: 0.9900
# Epoch 16: val_loss improved from 0.12409 to 0.12121, saving model to models/3-1/ch-016.ckpt
# INFO:tensorflow:Assets written to: models/3-1/ch-016.ckpt/assets
# INFO:tensorflow:Assets written to: models/3-1/ch-016.ckpt/assets
# 344/344 [==============================] - 26s 76ms/step - loss: 0.0297 - acc: 0.9900 - val_loss: 0.1212 - val_acc: 0.9638
# Epoch 17/30
# 344/344 [==============================] - ETA: 0s - loss: 0.0240 - acc: 0.9915
# Epoch 17: val_loss did not improve from 0.12121
# 344/344 [==============================] - 26s 74ms/step - loss: 0.0240 - acc: 0.9915 - val_loss: 0.1239 - val_acc: 0.9628
# Epoch 18/30
# 344/344 [==============================] - ETA: 0s - loss: 0.0196 - acc: 0.9938
# Epoch 18: val_loss did not improve from 0.12121
# 344/344 [==============================] - 29s 83ms/step - loss: 0.0196 - acc: 0.9938 - val_loss: 0.1456 - val_acc: 0.9644
# Epoch 19/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0186 - acc: 0.9935
# Epoch 19: val_loss did not improve from 0.12121
# 344/344 [==============================] - 25s 72ms/step - loss: 0.0186 - acc: 0.9935 - val_loss: 0.1284 - val_acc: 0.9650
# Epoch 20/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0153 - acc: 0.9956
# Epoch 20: val_loss did not improve from 0.12121
# 344/344 [==============================] - 26s 74ms/step - loss: 0.0153 - acc: 0.9956 - val_loss: 0.1486 - val_acc: 0.9638
# Epoch 21/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0121 - acc: 0.9967
# Epoch 21: val_loss did not improve from 0.12121
# 344/344 [==============================] - 25s 74ms/step - loss: 0.0121 - acc: 0.9967 - val_loss: 0.1785 - val_acc: 0.9592
# Epoch 22/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0113 - acc: 0.9965
# Epoch 22: val_loss did not improve from 0.12121
# 344/344 [==============================] - 26s 74ms/step - loss: 0.0112 - acc: 0.9965 - val_loss: 0.1507 - val_acc: 0.9664
# Epoch 23/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0073 - acc: 0.9985
# Epoch 23: val_loss did not improve from 0.12121
# 344/344 [==============================] - 25s 72ms/step - loss: 0.0073 - acc: 0.9985 - val_loss: 0.1549 - val_acc: 0.9662
# Epoch 24/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0058 - acc: 0.9986
# Epoch 24: val_loss did not improve from 0.12121
# 344/344 [==============================] - 26s 74ms/step - loss: 0.0058 - acc: 0.9986 - val_loss: 0.2209 - val_acc: 0.9566
# Epoch 25/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0078 - acc: 0.9974
# Epoch 25: val_loss did not improve from 0.12121
# 344/344 [==============================] - 26s 74ms/step - loss: 0.0078 - acc: 0.9974 - val_loss: 0.1803 - val_acc: 0.9662
# Epoch 26/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0051 - acc: 0.9986
# Epoch 26: val_loss did not improve from 0.12121
# 344/344 [==============================] - 26s 75ms/step - loss: 0.0051 - acc: 0.9986 - val_loss: 0.1610 - val_acc: 0.9660
# Epoch 27/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0020 - acc: 0.9997
# Epoch 27: val_loss did not improve from 0.12121
# 344/344 [==============================] - 26s 75ms/step - loss: 0.0020 - acc: 0.9997 - val_loss: 0.1789 - val_acc: 0.9680
# Epoch 28/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9990
# Epoch 28: val_loss did not improve from 0.12121
# 344/344 [==============================] - 26s 75ms/step - loss: 0.0043 - acc: 0.9990 - val_loss: 0.1741 - val_acc: 0.9672
# Epoch 29/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0019 - acc: 0.9996
# Epoch 29: val_loss did not improve from 0.12121
# 344/344 [==============================] - 26s 75ms/step - loss: 0.0019 - acc: 0.9996 - val_loss: 0.1912 - val_acc: 0.9690
# Epoch 30/30
# 343/344 [============================>.] - ETA: 0s - loss: 0.0018 - acc: 0.9997
# Epoch 30: val_loss did not improve from 0.12121
# 344/344 [==============================] - 26s 74ms/step - loss: 0.0018 - acc: 0.9997 - val_loss: 0.1829 - val_acc: 0.9688

# %%
val_loss, val_acc = model.evaluate(test_dataset, batch_size=64)
print(val_loss, val_acc)
# Out:
# 157/157 [==============================] - 4s 23ms/step - loss: 0.1829 - acc: 0.9688
# 0.1829010546207428 0.9688000082969666

# %%
model = keras.models.load_model('models/3-1/31-E.keras')

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.savefig("graphs/3-1/train_test_loss",dpi=100)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.savefig("graphs/3-1/train_test_acc",dpi=100)
plt.show()

# %%
img = tf.keras.preprocessing.image.load_img('../../Generator/Dataset_B/test/square/square_309.png', target_size=(IMG_SIZE, IMG_SIZE))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 img = tf.keras.preprocessing.image.load_img('../../Generator/Dataset_B/test/square/square_309.png', target_size=(IMG_SIZE, IMG_SIZE))
#
# File ~/miniconda3/envs/proj/lib/python3.11/site-packages/keras/src/utils/image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../Generator/Dataset_B/test/square/square_309.png'

# %%
img = tf.keras.preprocessing.image.load_img('../../Generator/Dataset_B/test/none/none_1.png', target_size=(IMG_SIZE, IMG_SIZE))

# %%
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
print(img_array.shape)
result = model.predict(img_array)
print("Result: ", result.round())

# %%
import csv
with open('results/3-1/results.csv', mode='w') as file:
    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(['Index', 'Label', 'Prediction'])
    for i, (data_batch, labels_batch) in enumerate(test_dataset):
        predictions = model.predict(data_batch)
        for j in range(len(predictions)):
            writer.writerow([i * BATCH_SIZE + j, labels_batch[j].numpy(), int(predictions[j][0].round())])
# Out:
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 69ms/step

# %%
with open('results/3-1/results.csv', mode='r') as file:
    csvFile = csv.reader(file)
    for lines in csvFile:
        if lines[1] != lines[2]:
            print(lines)
# Out:
# ['Index', 'Label', 'Prediction']
# ['18', '0', '1']
# ['171', '1', '0']
# ['274', '0', '1']
# ['300', '1', '0']
# ['318', '1', '0']
# ['348', '0', '1']
# ['358', '1', '0']
# ['375', '1', '0']
# ['439', '0', '1']
# ['502', '0', '1']
# ['533', '0', '1']
# ['545', '0', '1']
# ['564', '0', '1']
# ['613', '0', '1']
# ['655', '0', '1']
# ['699', '1', '0']
# ['702', '0', '1']
# ['713', '0', '1']
# ['749', '0', '1']
# ['856', '1', '0']
# ['920', '0', '1']
# ['954', '1', '0']
# ['995', '1', '0']
# ['999', '1', '0']
# ['1032', '1', '0']
# ['1034', '1', '0']
# ['1045', '1', '0']
# ['1056', '1', '0']
# ['1103', '0', '1']
# ['1109', '0', '1']
# ['1124', '0', '1']
# ['1130', '1', '0']
# ['1149', '0', '1']
# ['1170', '1', '0']
# ['1202', '1', '0']
# ['1207', '0', '1']
# ['1214', '0', '1']
# ['1236', '0', '1']
# ['1293', '0', '1']
# ['1302', '0', '1']
# ['1421', '1', '0']
# ['1427', '1', '0']
# ['1441', '1', '0']
# ['1454', '1', '0']
# ['1468', '0', '1']
# ['1474', '0', '1']
# ['1489', '0', '1']
# ['1504', '0', '1']
# ['1565', '1', '0']
# ['1630', '0', '1']
# ['1649', '0', '1']
# ['1670', '0', '1']
# ['1673', '0', '1']
# ['1717', '1', '0']
# ['1731', '0', '1']
# ['1752', '0', '1']
# ['1886', '1', '0']
# ['2012', '1', '0']
# ['2018', '0', '1']
# ['2020', '0', '1']
# ['2047', '0', '1']
# ['2078', '0', '1']
# ['2091', '0', '1']
# ['2163', '1', '0']
# ['2180', '1', '0']
# ['2221', '0', '1']
# ['2245', '1', '0']
# ['2299', '1', '0']
# ['2309', '0', '1']
# ['2312', '0', '1']
# ['2330', '0', '1']
# ['2362', '0', '1']
# ['2428', '1', '0']
# ['2504', '1', '0']
# ['2593', '1', '0']
# ['2595', '1', '0']
# ['2615', '0', '1']
# ['2623', '1', '0']
# ['2640', '0', '1']
# ['2670', '0', '1']
# ['2681', '0', '1']
# ['2747', '0', '1']
# ['2785', '0', '1']
# ['2795', '1', '0']
# ['2819', '1', '0']
# ['2848', '0', '1']
# ['2864', '1', '0']
# ['2914', '0', '1']
# ['2929', '0', '1']
# ['2936', '0', '1']
# ['2971', '0', '1']
# ['2985', '0', '1']
# ['3060', '0', '1']
# ['3130', '1', '0']
# ['3150', '1', '0']
# ['3203', '0', '1']
# ['3205', '1', '0']
# ['3221', '0', '1']
# ['3222', '1', '0']
# ['3232', '1', '0']
# ['3250', '1', '0']
# ['3263', '0', '1']
# ['3365', '1', '0']
# ['3378', '0', '1']
# ['3383', '0', '1']
# ['3393', '0', '1']
# ['3448', '1', '0']
# ['3545', '1', '0']
# ['3560', '0', '1']
# ['3602', '1', '0']
# ['3616', '1', '0']
# ['3623', '1', '0']
# ['3647', '1', '0']
# ['3654', '1', '0']
# ['3783', '0', '1']
# ['3840', '1', '0']
# ['3914', '1', '0']
# ['3928', '1', '0']
# ['3947', '1', '0']
# ['3970', '1', '0']
# ['3997', '1', '0']
# ['4017', '0', '1']
# ['4031', '0', '1']
# ['4107', '0', '1']
# ['4146', '1', '0']
# ['4158', '1', '0']
# ['4174', '0', '1']
# ['4177', '0', '1']
# ['4178', '1', '0']
# ['4194', '1', '0']
# ['4221', '0', '1']
# ['4248', '0', '1']
# ['4263', '0', '1']
# ['4268', '0', '1']
# ['4276', '0', '1']
# ['4304', '0', '1']
# ['4338', '0', '1']
# ['4405', '0', '1']
# ['4409', '0', '1']
# ['4508', '0', '1']
# ['4578', '0', '1']
# ['4591', '1', '0']
# ['4595', '1', '0']
# ['4613', '1', '0']
# ['4622', '0', '1']
# ['4645', '0', '1']
# ['4658', '1', '0']
# ['4670', '0', '1']
# ['4790', '0', '1']
# ['4821', '1', '0']
# ['4862', '1', '0']
# ['4876', '1', '0']
# ['4884', '1', '0']
# ['4925', '0', '1']
# ['4978', '0', '1']
# ['4995', '1', '0']

# %%
file_paths = []
wrong_filenames = []
count = 0
file_idx = 0

# make sure we start in the beginning
test_dataset = image_dataset_from_directory(
    test_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=1,
    shuffle=False
    )
    
file_paths = test_dataset.file_paths
for data_batch, labels_batch in test_dataset:

    predictions = model.predict(data_batch).flatten()
    predictions = predictions.round()
    predictions = predictions.astype(int)
    labels_batch = labels_batch.numpy()
    #pred_str = np.array2string(predictions, separator=', ')
    #label_str = np.array2string(labels_batch, separator=', ')
    for i in range(len(data_batch)):
        if labels_batch[i] != predictions[i]:
            wrong_filenames.append(file_paths[file_idx])
    file_idx += 1

# print(f"Predictions: {pred_str}")
# print(f"Labels: {label_str}")
print(file_idx)
print(count)
print(len(wrong_filenames))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 file_idx = 0
#       6 # make sure we start in the beginning
# ----> 7 test_dataset = image_dataset_from_directory(
#       8     test_dir,
#       9     image_size=(IMG_SIZE, IMG_SIZE),
#      10     batch_size=1,
#      11     shuffle=False
#      12     )
#      14 file_paths = test_dataset.file_paths
#      15 for data_batch, labels_batch in test_dataset:
#
# NameError: name 'image_dataset_from_directory' is not defined
