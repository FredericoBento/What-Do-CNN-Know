# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import layers
tf.config.list_physical_devices('GPU')
# Out:
# 2024-05-21 16:17:16.375173: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-21 16:17:16.375312: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-21 16:17:16.377649: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-21 16:17:16.385743: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-21 16:17:17.528380: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-05-21 16:17:18.902630: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-21 16:17:18.937053: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-21 16:17:18.937369: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
train_dir = '../../Dataset_Scripts/Datasets/Dataset_R2/train/circles/'
test_dir = '../../Dataset_Scripts/Datasets/Dataset_R2/test/circles/'

# %%
IMG_SIZE = 250
BATCH_SIZE = 32

# %%
import pandas as pd
data_df = pd.read_csv('../../Dataset_Scripts/Datasets/Dataset_R2/data/circles_small.csv')
train_df = data_df[data_df['Variant'] == 'Train']
test_df = data_df[data_df['Variant'] == 'Test']

# %%
# Remove other columns and keep only the 'Proportion' and Filename columns
train_df = train_df[['Proportion', 'Filename']]
test_df = test_df[['Proportion', 'Filename']]

# %%
print(train_df.head())
# Out:
#    Proportion       Filename
# 0       0.800  circles_1.png
# 1       0.973  circles_2.png
# 2       0.416  circles_3.png
# 3       0.300  circles_4.png
# 4       0.307  circles_5.png

# %%
gen = keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

train_generator = gen.flow_from_dataframe(
    dataframe=train_df,
    directory=train_dir,
    x_col='Filename',
    y_col='Proportion',
    target_size=(IMG_SIZE, IMG_SIZE),
    class_mode='raw',
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_generator = gen.flow_from_dataframe(
    dataframe=test_df,
    directory=test_dir,
    x_col='Filename',
    y_col='Proportion',
    target_size=(IMG_SIZE, IMG_SIZE),
    class_mode='raw',
    batch_size=BATCH_SIZE,
    shuffle=True
)
# Out:
# Found 10999 validated image filenames.
# Found 4999 validated image filenames.

# %%
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
x = layers.Dense(512, activation="relu")(x)
outputs = layers.Dense(1, activation="sigmoid")(x) 
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(loss="mse", optimizer="adam" , metrics=["mae"])

# %%
checkpoint_filepath = 'models/R2_Sigmoid/ch-{epoch:03d}.ckpt'
model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_best_only=True,
    monitor='val_loss',
    verbose=1
)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    verbose=1
)

callbacks = [model_checkpoint, early_stop]

# %%
history = model.fit(train_generator, epochs=100, batch_size=32, verbose=1, validation_data=test_generator, callbacks=[callbacks])
# Out:
# Epoch 1/100
# 344/344 [==============================] - ETA: 0s - loss: 0.3191 - mae: 0.4901
# Epoch 1: val_loss improved from inf to 0.32219, saving model to models/R2_Sigmoid/ch-001.ckpt
# INFO:tensorflow:Assets written to: models/R2_Sigmoid/ch-001.ckpt/assets
# INFO:tensorflow:Assets written to: models/R2_Sigmoid/ch-001.ckpt/assets
# 344/344 [==============================] - 80s 233ms/step - loss: 0.3191 - mae: 0.4901 - val_loss: 0.3222 - val_mae: 0.4930
# Epoch 2/100
# 344/344 [==============================] - ETA: 0s - loss: 0.3191 - mae: 0.4901
# Epoch 2: val_loss did not improve from 0.32219
# 344/344 [==============================] - 77s 223ms/step - loss: 0.3191 - mae: 0.4901 - val_loss: 0.3222 - val_mae: 0.4930
# Epoch 3/100
# 344/344 [==============================] - ETA: 0s - loss: 0.3191 - mae: 0.4901
# Epoch 3: val_loss improved from 0.32219 to 0.32219, saving model to models/R2_Sigmoid/ch-003.ckpt
# INFO:tensorflow:Assets written to: models/R2_Sigmoid/ch-003.ckpt/assets
# INFO:tensorflow:Assets written to: models/R2_Sigmoid/ch-003.ckpt/assets
# 344/344 [==============================] - 77s 223ms/step - loss: 0.3191 - mae: 0.4901 - val_loss: 0.3222 - val_mae: 0.4930
# Epoch 4/100
# 344/344 [==============================] - ETA: 0s - loss: 0.3191 - mae: 0.4901
# Epoch 4: val_loss did not improve from 0.32219
# 344/344 [==============================] - 100s 290ms/step - loss: 0.3191 - mae: 0.4901 - val_loss: 0.3222 - val_mae: 0.4930
# Epoch 5/100
# 344/344 [==============================] - ETA: 0s - loss: 0.3191 - mae: 0.4901
# Epoch 5: val_loss did not improve from 0.32219
# 344/344 [==============================] - 70s 205ms/step - loss: 0.3191 - mae: 0.4901 - val_loss: 0.3222 - val_mae: 0.4930
# Epoch 6/100
# 344/344 [==============================] - ETA: 0s - loss: 0.3191 - mae: 0.4901
# Epoch 6: val_loss did not improve from 0.32219
# 344/344 [==============================] - 74s 216ms/step - loss: 0.3191 - mae: 0.4901 - val_loss: 0.3222 - val_mae: 0.4930
# Epoch 7/100
# 344/344 [==============================] - ETA: 0s - loss: 0.3191 - mae: 0.4901
# Epoch 7: val_loss did not improve from 0.32219
# 344/344 [==============================] - 71s 207ms/step - loss: 0.3191 - mae: 0.4901 - val_loss: 0.3222 - val_mae: 0.4930
# Epoch 8/100
# 344/344 [==============================] - ETA: 0s - loss: 0.3191 - mae: 0.4901
# Epoch 8: val_loss did not improve from 0.32219
# 344/344 [==============================] - 84s 245ms/step - loss: 0.3191 - mae: 0.4901 - val_loss: 0.3222 - val_mae: 0.4930
# Epoch 8: early stopping

# %%
# save history to file
import pickle
with open('models/R2_Sigmoid/history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
# save model
model.save('models/R2_Sigmoid/model.keras')

# %%
loss = model.evaluate(test_generator)
# Out:
# 157/157 [==============================] - 38s 244ms/step - loss: 0.3222 - mae: 0.4930

# %%
import seaborn as sns
sns.pairplot(train_df, diag_kind='kde')

# %%
new_genetator = gen.flow_from_dataframe(
    dataframe=test_df,
    directory=test_dir,
    x_col='Filename',
    y_col='Proportion',
    target_size=(IMG_SIZE, IMG_SIZE),
    class_mode='raw',
    batch_size=1,
)
# Out:
# Found 4999 validated image filenames.

# %%
# run thorugh all batches in the test generator and save predictions and true values into a csv
predictions = []
true_values = []

for i in range(len(new_genetator)):
    x, y = test_generator[i]
    predictions += list(model.predict(x).flatten())
    true_values += list(y)
# Out:
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 99ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 6
#       3 true_values = []
#       5 for i in range(len(new_genetator)):
# ----> 6     x, y = test_generator[i]
#       7     predictions += list(model.predict(x).flatten())
#       8     true_values += list(y)
#
# File ~/.local/lib/python3.11/site-packages/keras/src/preprocessing/image.py:103, in Iterator.__getitem__(self, idx)
#     101 def __getitem__(self, idx):
#     102     if idx >= len(self):
# --> 103         raise ValueError(
#     104             "Asked to retrieve element {idx}, "
#     105             "but the Sequence "
#     106             "has length {length}".format(idx=idx, length=len(self))
#     107         )
#     108     if self.seed is not None:
#     109         np.random.seed(self.seed + self.total_batches_seen)
#
# ValueError: Asked to retrieve element 157, but the Sequence has length 157

# %%
df = pd.DataFrame({'True Proportion': true_values, 'Predicted Proportion': predictions, 'Difference': np.abs(np.array(true_values) - np.array(predictions))}, index=new_genetator.filenames)
df.to_csv('predictions.csv')

# %%
# plot of loss
plt.plot(history.history['loss'])
#plt.savefig('graphs/loss.png')

# %%
plt.plot(history.history['val_loss'])

# %%
# plot of mean absolute error
plt.plot(history.history['mae'])
plt.savefig('graphs/mae.png')

# %%
plt.plot(history.history['val_mae'])
